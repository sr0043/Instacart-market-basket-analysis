# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-09574db9-617b-4f6d-bbdd-7f16ac4dfab6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-09574db9-617b-4f6d-bbdd-7f16ac4dfab6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-a12d9800-43bc-4873-9ecd-e8022ad71dbf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a12d9800-43bc-4873-9ecd-e8022ad71dbf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-8190f998-7448-4239-b2c6-55f27771c823" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8190f998-7448-4239-b2c6-55f27771c823">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-9f687ec2-4f7b-48c5-ad07-5715ca4d347c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f687ec2-4f7b-48c5-ad07-5715ca4d347c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-a0998cdf-d43c-4248-a0d2-7bbeac875d2f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a0998cdf-d43c-4248-a0d2-7bbeac875d2f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-ec5db183-4096-4ad4-8ce4-0072f1e399dc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ec5db183-4096-4ad4-8ce4-0072f1e399dc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
orders= pd.read_excel("orders.xlsx")
print(orders)
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 1048570   1805240    63100    prior             1          0
# 1048571   2719402    63100    prior             2          0
# 1048572   2855250    63100    prior             3          2
# 1048573   2355832    63100    prior             4          5
# 1048574   2362552    63100    train             5          1
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
products= pd.read_excel("products.xlsx")
print(products)
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49683       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49684       49685                 En Croute Roast Hazelnut Cranberry
# 49685       49686                                   Artisan Baguette
# 49686       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49687       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# ...

# %%
departments= pd.read_excel("departments.xlsx")
print(departments)
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing

# %%
aisles= pd.read_excel("aisles.xlsx")
print(aisles)
# Out:
#      aisle_id                       aisle
# 0           1       prepared soups salads
# 1           2           specialty cheeses
# 2           3         energy granola bars
# 3           4               instant foods
# 4           5  marinades meat preparation
# ..        ...                         ...
# 129       130    hot cereal pancake mixes
# 130       131                   dry pasta
# 131       132                      beauty
# 132       133  muscles joints pain relief
# 133       134  specialty wines champagnes
#
# [134 rows x 2 columns]

# %%
o_p_p= pd.read_excel("order_products__prior.xlsx")
print(o_p_p)
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0               2       33120                  1          1
# 1               2       28985                  2          1
# 2               2        9327                  3          0
# 3               2       45918                  4          1
# 4               2       30035                  5          0
# ...           ...         ...                ...        ...
# 1048570    110719       26209                  1          0
# 1048571    110719       35140                  2          0
# 1048572    110720       28849                  1          1
# 1048573    110720       35594                  2          0
# 1048574    110720       16185                  3          1
#
# [1048575 rows x 4 columns]

# %%
o_p_t= pd.read_excel("order_products__train.xlsx")
print(o_p_t)
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0               1       49302                  1          1
# 1               1       11109                  2          1
# 2               1       10246                  3          0
# 3               1       49683                  4          0
# 4               1       43633                  5          1
# ...           ...         ...                ...        ...
# 1048570   2593147       44142                  3          0
# 1048571   2593147       34969                  4          1
# 1048572   2593147       33055                  5          0
# 1048573   2593147       16185                  6          1
# 1048574   2593147        7364                  7          0
#
# [1048575 rows x 4 columns]

# %%
aisles.isnull().sum()
# Out:
# aisle_id    0
# aisle       0
# dtype: int64

# %%
departments.isnull().sum()
# Out:
# department_id    0
# department       0
# dtype: int64

# %%
orders.isnull().sum()
# Out:
# order_id                      0
# user_id                       0
# eval_set                      0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    63100
# dtype: int64

# %%
products.nunique()
# Out:
# product_id       49688
# product_name     49687
# aisle_id           134
# department_id       21
# dtype: int64

# %%
products.isnull().sum()
# Out:
# product_id       0
# product_name     1
# aisle_id         0
# department_id    0
# dtype: int64

# %%
orders.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.710968e+06  3.156404e+04  1.717418e+01  2.778637e+00
# std    9.875774e+05  1.816695e+04  1.771094e+01  2.047751e+00
# min    6.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.554670e+05  1.589600e+04  5.000000e+00  1.000000e+00
# 50%    1.710657e+06  3.160800e+04  1.100000e+01  3.000000e+00
# 75%    2.566970e+06  4.729700e+04  2.300000e+01  5.000000e+00
# max    3.421083e+06  6.310000e+04  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       1.048575e+06           985475.000000
# mean        1.345229e+01               11.102506
# std         4.219144e+00                9.186663
# min         0.000000e+00                0.000000
# 25%         1.000000e+01                4.000000
# 50%         1.300000e+01                7.000000
# 75%         1.600000e+01               15.000000
# ...

# %%
mv=orders["days_since_prior_order"].mean()
orders["days_since_prior_order"].fillna(mv,inplace=True)

# %%
orders.isnull().sum()
# Out:
# order_id                  0
# user_id                   0
# eval_set                  0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# dtype: int64

# %% [markdown]
# ### Merge tables

# %%
order_products = pd.concat([o_p_t,o_p_p])
order_products = order_products.merge(orders, on = 'order_id', how='left').merge(products, on = 'product_id', how = 'left').merge(departments, on = 'department_id').merge(aisles, on = 'aisle_id')

# %%
order_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2097150 entries, 0 to 2097149
# Data columns (total 15 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   product_id              int64
#  2   add_to_cart_order       int64
#  3   reordered               int64
#  4   user_id                 float64
#  5   eval_set                object
#  6   order_number            float64
#  7   order_dow               float64
#  8   order_hour_of_day       float64
#  9   days_since_prior_order  float64
#  10  product_name            object
#  11  aisle_id                int64
#  12  department_id           int64
#  13  department              object
#  14  aisle                   object
# dtypes: float64(5), int64(6), object(4)
# memory usage: 240.0+ MB

# %% [markdown]
# # EDA

# %%
total_orders = order_products['order_id'].nunique()
print('tatal_order:', total_orders)
# Out:
# tatal_order: 203616

# %% [markdown]
# **There are a total of 203616 orders placed.**

# %%
total_customers = order_products['user_id'].nunique()
print('total_customers:', total_customers)
# Out:
# total_customers: 41234

# %% [markdown]
# **There are a total of 41,234 customer details available.**

# %%
product_count = order_products.groupby('department')['product_id'].nunique().sort_values(ascending=False)
plt.figure(figsize=(9,5))
plt.title('Number of products in each department')
plt.bar(product_count.index, product_count.values, color='green')
plt.xlabel('Department')
plt.ylabel('Number of products')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
aisles_count = order_products.groupby('department')['aisle_id'].nunique().sort_values(ascending=False)
plt.figure(figsize=(9,5))
plt.title('Number of aisles in each department')
plt.bar(aisles_count.index, aisles_count.values, color='orange')
plt.xlabel('Department')
plt.ylabel('Number of aisles')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# **Insights**
#
#
# * There are total 21 departments.
# *  The snacks department has more products in it.
# * In personal care department has more number aisle.

# %%
total_prod_count = order_products.shape[0]
reorder_ratio = order_products['reordered'].value_counts()/total_prod_count*100
ax = sns.barplot(x=reorder_ratio.index, y=reorder_ratio.values, color='green')
ax.set_xticklabels(['non-reorder', 'reordered'])
plt.title('Reordered ratio')
plt.show()
# Out:
# <ipython-input-66-16ddacec766e>:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['non-reorder', 'reordered'])

# %%
peak_days = order_products['order_dow'].value_counts().sort_index()
plt.figure(figsize=(7,3))
plt.title('peak days')
plt.bar(peak_days.index, peak_days.values, color='orange')
plt.xlabel('Days')
plt.ylabel('Orders Count')
plt.xticks(range(0,7), ['Sunday', 'Monday','Tuesday','Wednesday','Thursday','Friday','Saturday'])
plt.show()

# %%
peak_hours = order_products['order_hour_of_day'].value_counts().sort_index()
plt.figure(figsize=(7,3))
plt.title('peak Hours')
plt.bar(peak_hours.index, peak_hours.values, color='green')
plt.xlabel('Hours')
plt.ylabel('Orders Count')
plt.xticks(range(0,24),)
plt.show()

# %%
last_order = order_products['days_since_prior_order'].value_counts().sort_index()
plt.figure(figsize=(7,3))
plt.title('Last purchases days')
plt.bar(last_order.index, last_order.values, color='orange')
plt.xlabel('number of days')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Insights**
# * More than 55% of people reorded products.
# * Sunday and Monday are the two days of peak orders of the week.
# * 9am to 4pm is the peak hours of the days.
# * Most of people order products in every 30 days.
# * Some people also order products in weekly.

# %%
order_count = order_products[order_products['order_id'] == 1]
order_department = order_count['department'].value_counts()
plt.figure(figsize=(7,6))
plt.title('Top ordered Departments')
plt.xlabel('order counts')
plt.ylabel('Departments')
plt.barh(y=order_department.index, width=order_department.values, color='green')
plt.gca().invert_yaxis()
plt.show()

# %%
reorder_count = order_products[order_products['reordered'] == 1]
reorder_department = reorder_count['department'].value_counts()
plt.figure(figsize=(7,6))
plt.title('Top Reordered Departments')
plt.xlabel('Reorder counts')
plt.ylabel('Departments')
plt.barh(y=reorder_department.index, width=reorder_department.values, color='orange')
plt.gca().invert_yaxis()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# **Insights**
# * Produce and dairy eggs took first and second place for both order and reorder departments.

# %%
top_product = order_products['product_name'].value_counts().head(10).sort_values(ascending=True)
plt.figure(figsize=(7,5))
plt.barh(y=top_product.index, width=top_product.values,color='green')
plt.title('Top order products')
plt.xlabel('Frequency')
plt.ylabel('product')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
reorder_count = order_products[order_products['reordered'] == 1]
reorder_products = reorder_count['product_name'].value_counts().nlargest(10)
plt.figure(figsize=(7,5))
plt.title('Top Reordered Product')
plt.barh(y=reorder_products.index, width=reorder_products.values, color='orange')
plt.xlabel('Reorder count')
plt.ylabel('Products')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# **Insights**
# * Banana and bag of organic bananas took first and second place for both order and reorder products.

# %%
reorder_count = order_products[order_products['reordered'] == 1]
reorder_aisles = reorder_count['aisle'].value_counts().nlargest(10)
plt.figure(figsize=(7,5))
plt.title('Top reorder aisles')
plt.ylabel('Reorder count')
plt.xlabel('Aisles')
plt.bar(reorder_aisles.index, reorder_aisles.values, color='green')
plt.xticks(rotation=90)
plt.show()

# %%
by_aisle = order_products.groupby(['aisle']).agg({'product_id':'count'}).reset_index().rename(columns={'product_id':'products_count'})
top = by_aisle.nlargest(10, columns='products_count')

plt.figure(figsize=(8, 6))
plt.barh(y=top['aisle'], width=top['products_count'], color = 'orange')
plt.xlabel('Number of products')
plt.ylabel('Aisle')
plt.title('Number of products ordered in each aisle')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# **Insights**
# * Fresh fruits and fresh vegetables took first and second place for both order and reorder products.

# %%
temp_df = order_products.groupby(["order_dow", "order_hour_of_day"])["order_number"].aggregate("count").reset_index()
temp_df = temp_df.pivot(index='order_dow', columns='order_hour_of_day', values='order_number')
ax = plt.subplots(figsize=(7,3))

ax = sns.heatmap(temp_df, cmap="YlOrBr", linewidths=.5)
ax.set_title("Frequency of Day of week Vs Hour of day", size = 12)
ax.set_xlabel("Hour of Day", size = 10)
ax.set_ylabel("Day of Week", size = 10)
ax.tick_params(axis = 'both', labelsize = 8)
cbar = ax.collections[0].colorbar
cbar.ax.tick_params(labelsize=10)
fig = ax.get_figure()
plt.show()

# %% [markdown]
# **Insights**
# * Sunday morning 8 to evening 5 o clock is the peak order peroid.
# * Monday moring 9 to 11 only peak time after that orders counts start to decrease slightly.

# %%
pip install apyori
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5955 sha256=f716d9382de054e703aca3e8faa793088a405e32c35ec01029227eb13c9970ea
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# ...

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
group_op = order_products.groupby(['order_id']).agg({
    'reordered': 'mean',
    'order_number': 'first'
}).reset_index().rename(columns={'reordered': 'reorder_ratio'})
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
group_op = order_products.groupby(['add_to_cart_order']).agg({
    'reordered': 'mean'
}).rename(columns={'reordered': 'reorder_ratio'}).reset_index()
plt.figure(figsize=(7,5))
sns.lineplot(x=group_op['add_to_cart_order'], y=group_op['reorder_ratio'], color='green')
plt.title('Reorder add to cart products')
plt.xlabel('add to cart products')
plt.ylabel('Reorder count')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# **Insights**
# * 70% of reorders are only for the first items in the add to cart.
# * All items with an add to cart position below the 20th have a reorder rate below 40%.
# * All 90th add to cart items have a 0% reorder rate.

# %%
min_support =0.0001
min_confidence = 0.05
rfm = order_products.groupby('order_id')['product_name'].apply(list)
rfm.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# order_id
# 1    [Bulgarian Yogurt, Organic 4% Milk Fat Whole M...
# 2    [Organic Egg Whites, Michigan Organic Kale, Ca...
# 3    [Total 2% with Strawberry Lowfat Greek Straine...
# 4    [Original Orange Juice, Sugarfree Energy Drink...
# 5    [Mini Original Babybel Cheese, American Slices...
# Name: product_name, dtype: object

# %%
frequent_itemsets = apriori(rfm, min_support, use_colnames=True)

# %%
def calculate_support(transaction_series, r=1):counts = Counter()
for transaction in rfm:counts.update(combinations(transaction, r))
num_transactions = len(rfm)
support = {item: count / num_transactions for item, count in counts.items()}
  return support

def generate_frequent_itemsets(transaction_series, min_support, r):support = calculate_support(transaction_series, r)
frequent_itemsets = {itemset for itemset, count in support.items() if count >= min_support}
  return frequent_itemsets
frequent_itemsets = generate_frequent_itemsets(rfm, min_support, 2)
support1 = calculate_support(rfm, 1)
support2 = calculate_support(rfm, 2)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-1dcf8d89b8ef> in <cell line: 2>()
#       1 def calculate_support(transaction_series, r=1):counts = Counter()
# ----> 2 for transaction in rfm:counts.update(combinations(transaction, r))
#       3 num_transactions = len(rfm)
#       4 support = {item: count / num_transactions for item, count in counts.items()}
#       5 return support
#
# NameError: name 'rfm' is not defined

# %%
def generate_association_rules(frequent_itemsets, rfm, support1,support2,min_support,min_confidence):
    association_rules = []
    for itemset in frequent_itemsets:
        antecedent = itemset[0]
        consequent = itemset[1]
        rule_support = support2[itemset]
        rule_confidence = rule_support / support1[(antecedent,)]
        if rule_support >= min_support and rule_confidence >= min_confidence:
            association_rules.append((antecedent, consequent, rule_support, rule_confidence))
    return association_rules

association_rules = generate_association_rules(frequent_itemsets, rfm,support1,support2,min_support, min_confidence)
association_rules_pd = pd.DataFrame(association_rules, columns = ["antecedent", "consequent", "support", "confidence"])
association_rules_pd = association_rules_pd.sort_values(["antecedent","confidence"],ascending= False)
associations = association_rules_pd.groupby(["antecedent"])["consequent"].apply(list).reset_index()

# %%
df_encoded = pd.get_dummies(df['Items'].apply(pd.Series).stack()).sum(level=0)

frequent_itemsets = apriori(df_encoded, min_support=0.3, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

print("Frequent Itemsets:",frequent_itemsets)
print("\nAssociation Rules:",rules)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-00a7e5eb79d3> in <cell line: 1>()
# ----> 1 frequent_itemsets = apriori(rfm, min_support, use_colnames=True)
#
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/apriori.py in apriori(df, min_support, use_colnames, max_len, verbose, low_memory)
#     239         )
#     240
# --> 241     fpc.valid_input_check(df)
#     242
#     243     if hasattr(df, "sparse"):
#
# ...

# %%
basket = order_products.pivot_table(columns='product_name', values='reordered', index='order_id').reset_index().fillna(0).set_index('order_id')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dcec025d5628> in <cell line: 1>()
# ----> 1 basket = order_products.pivot_table(columns='product_name', values='reordered', index='order_id').reset_index().fillna(0).set_index('order_id')
#
# NameError: name 'order_products' is not defined

# %% [markdown]
# **Conclution**
# * Givien data was excellent.
# * Only one column have 6% empty values.
# * There are 59% of customers reorder the products.
# * Most of the reorder was happened in "Produce" and "Dairy eggs" departments.
# * Sunday is a peak orders day of the week.
# * 9am to 4pm is the peak hours of the days.
# * Most number of people order after a 30 days gap.
# * Some people order a products weekly.
#
# ### **Recommendations**
# * By placing personal care aisle arount both Produce and dairy eggs two department aisles, can increase our sales.
# * Wednesday and thursday people are no interseted to buy a products. So that time we can give some discounts, it helps increase our sales.
# * Some people buy products in weekly. we target these customer, to give some special offer or voucher.
# * Throught this we can retain our customers and our sales will increase.
